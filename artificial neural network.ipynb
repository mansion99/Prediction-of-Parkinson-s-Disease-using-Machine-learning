# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
# %matplotlib inline

# %%
names=["name","MDVP:Fo(Hz)","MDVP:Fhi(Hz)","MDVP:Flo(Hz)","MDVP:Jitter(%)","MDVP:Jitter(Abs)","MDVP:RAP","MDVP:PPQ","Jitter:DDP","MDVP:Shimmer","MDVP:Shimmer(dB)","Shimmer:APQ3","Shimmer:APQ5","MDVP:APQ","Shimmer:DDA","NHR","HNR","status","RPDE","DFA","spread1","spread2","D2","PPE"]
df =pd.read_csv("parkinsons.csv",names=names)
df.drop(['name'],axis=1,inplace=True)
df.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.813031
# 2      0.08270  0.00000  20.651       1  0.429895  0.825288 -4.813031
# 3      0.08771  0.00000  20.644       1  0.434969  0.845379 -4.813031
# 4      0.10470  0.00000  19.649       1  0.417356  0.845379 -4.813031
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.234513  2.332180  0.410335
#
# [5 rows x 23 columns]

# %%
X = df.drop('status', axis=1)
Y = df['status']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y,test_size=0.30,random_state = 1)
y_train=y_train.astype('int')

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 22))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 34944/34944 [==============================] - 9s 257us/step - loss: 0.2723 - accuracy: 0.8902
# Epoch 2/100
# 34944/34944 [==============================] - 7s 193us/step - loss: 0.1999 - accuracy: 0.9211
# Epoch 3/100
# 34944/34944 [==============================] - 6s 172us/step - loss: 0.1824 - accuracy: 0.9274
# Epoch 4/100
# 34944/34944 [==============================] - 7s 206us/step - loss: 0.1588 - accuracy: 0.9293
# Epoch 5/100
# 34944/34944 [==============================] - 7s 202us/step - loss: 0.1283 - accuracy: 0.9335
# Epoch 6/100
# 34944/34944 [==============================] - 7s 186us/step - loss: 0.1133 - accuracy: 0.9479
# Epoch 7/100
# 34944/34944 [==============================] - 7s 210us/step - loss: 0.1061 - accuracy: 0.9538
# Epoch 8/100
# 34944/34944 [==============================] - 9s 247us/step - loss: 0.1007 - accuracy: 0.9590
# Epoch 9/100
# 34944/34944 [==============================] - 7s 196us/step - loss: 0.0921 - accuracy: 0.9673
# Epoch 10/100
# 34944/34944 [==============================] - 7s 207us/step - loss: 0.0845 - accuracy: 0.9728
# Epoch 11/100
# 34944/34944 [==============================] - 7s 213us/step - loss: 0.0821 - accuracy: 0.9738
# Epoch 12/100
# 34944/34944 [==============================] - 9s 257us/step - loss: 0.0797 - accuracy: 0.9741
# Epoch 13/100
# 34944/34944 [==============================] - 9s 257us/step - loss: 0.0772 - accuracy: 0.9748
# Epoch 14/100
# 34944/34944 [==============================] - 7s 213us/step - loss: 0.0768 - accuracy: 0.9752
# Epoch 15/100
# 34944/34944 [==============================] - 7s 212us/step - loss: 0.0748 - accuracy: 0.9764
# Epoch 16/100
# 34944/34944 [==============================] - 8s 223us/step - loss: 0.0727 - accuracy: 0.9768
# Epoch 17/100
# 34944/34944 [==============================] - 7s 211us/step - loss: 0.0714 - accuracy: 0.9777
# Epoch 18/100
# 34944/34944 [==============================] - 7s 206us/step - loss: 0.0706 - accuracy: 0.9774
# Epoch 19/100
# 34944/34944 [==============================] - 7s 198us/step - loss: 0.0700 - accuracy: 0.9774
# Epoch 20/100
# 34944/34944 [==============================] - 7s 186us/step - loss: 0.0682 - accuracy: 0.9788
# Epoch 21/100
# 34944/34944 [==============================] - 6s 181us/step - loss: 0.0661 - accuracy: 0.9782
# Epoch 22/100
# 34944/34944 [==============================] - 6s 179us/step - loss: 0.0641 - accuracy: 0.9797
# Epoch 23/100
# 34944/34944 [==============================] - 7s 191us/step - loss: 0.0630 - accuracy: 0.9796
# Epoch 24/100
# 34944/34944 [==============================] - 6s 185us/step - loss: 0.0616 - accuracy: 0.9800
# Epoch 25/100
# 34944/34944 [==============================] - 7s 211us/step - loss: 0.0617 - accuracy: 0.9802
# Epoch 26/100
# 34944/34944 [==============================] - 7s 191us/step - loss: 0.0593 - accuracy: 0.9800
# Epoch 27/100
# 34944/34944 [==============================] - 6s 183us/step - loss: 0.0593 - accuracy: 0.9808
# Epoch 28/100
# 34944/34944 [==============================] - 6s 180us/step - loss: 0.0588 - accuracy: 0.9803
# Epoch 29/100
# 34944/34944 [==============================] - 6s 181us/step - loss: 0.0587 - accuracy: 0.9808
# Epoch 30/100
# 34944/34944 [==============================] - 6s 178us/step - loss: 0.0580 - accuracy: 0.9806
# Epoch 31/100
# 34944/34944 [==============================] - 6s 182us/step - loss: 0.0573 - accuracy: 0.9810
# Epoch 32/100
# 34944/34944 [==============================] - 7s 199us/step - loss: 0.0570 - accuracy: 0.9811
# Epoch 33/100
# 34944/34944 [==============================] - 7s 205us/step - loss: 0.0563 - accuracy: 0.9812
# Epoch 34/100
# 34944/34944 [==============================] - 6s 184us/step - loss: 0.0555 - accuracy: 0.9811
# Epoch 35/100
# 34944/34944 [==============================] - 6s 176us/step - loss: 0.0553 - accuracy: 0.9815
# Epoch 36/100
# 34944/34944 [==============================] - 6s 185us/step - loss: 0.0545 - accuracy: 0.9818
# Epoch 37/100
# 34944/34944 [==============================] - 7s 200us/step - loss: 0.0539 - accuracy: 0.9815
# Epoch 38/100
# 34944/34944 [==============================] - 8s 216us/step - loss: 0.0535 - accuracy: 0.9818
# Epoch 39/100
# 34944/34944 [==============================] - 6s 180us/step - loss: 0.0547 - accuracy: 0.9817
# Epoch 40/100
# 34944/34944 [==============================] - 6s 163us/step - loss: 0.0532 - accuracy: 0.9819
# Epoch 41/100
# 34944/34944 [==============================] - 8s 231us/step - loss: 0.0537 - accuracy: 0.9817
# Epoch 42/100
# 34944/34944 [==============================] - ETA: 0s - loss: 0.0538 - accuracy: 0.98 - 9s 261us/step - loss: 0.0537 - accuracy: 0.9820
# Epoch 43/100
# 34944/34944 [==============================] - 8s 224us/step - loss: 0.0510 - accuracy: 0.9837
# Epoch 44/100
# 34944/34944 [==============================] - 7s 195us/step - loss: 0.0491 - accuracy: 0.9842
# Epoch 45/100
# 34944/34944 [==============================] - 7s 195us/step - loss: 0.0484 - accuracy: 0.9856
# Epoch 46/100
# 34944/34944 [==============================] - 7s 195us/step - loss: 0.0474 - accuracy: 0.9861
# Epoch 47/100
# 34944/34944 [==============================] - 7s 204us/step - loss: 0.0471 - accuracy: 0.9862
# Epoch 48/100
# 34944/34944 [==============================] - 7s 203us/step - loss: 0.0463 - accuracy: 0.9860
# Epoch 49/100
# 34944/34944 [==============================] - 8s 231us/step - loss: 0.0461 - accuracy: 0.9862
# Epoch 50/100
# 34944/34944 [==============================] - 8s 242us/step - loss: 0.0459 - accuracy: 0.9866
# Epoch 51/100
# 34944/34944 [==============================] - 7s 214us/step - loss: 0.0449 - accuracy: 0.9866
# Epoch 52/100
# 34944/34944 [==============================] - 7s 204us/step - loss: 0.0446 - accuracy: 0.9869
# Epoch 53/100
# 34944/34944 [==============================] - 7s 191us/step - loss: 0.0438 - accuracy: 0.9871
# Epoch 54/100
# 34944/34944 [==============================] - 7s 189us/step - loss: 0.0433 - accuracy: 0.9874
# Epoch 55/100
# 34944/34944 [==============================] - 7s 189us/step - loss: 0.0444 - accuracy: 0.9864
# Epoch 56/100
# 34944/34944 [==============================] - 6s 183us/step - loss: 0.0444 - accuracy: 0.9869
# Epoch 57/100
# 34944/34944 [==============================] - 7s 201us/step - loss: 0.0432 - accuracy: 0.9872
# Epoch 58/100
# 34944/34944 [==============================] - 8s 216us/step - loss: 0.0437 - accuracy: 0.9870
# Epoch 59/100
# 34944/34944 [==============================] - 7s 200us/step - loss: 0.0428 - accuracy: 0.9874
# Epoch 60/100
# 34944/34944 [==============================] - 7s 187us/step - loss: 0.0429 - accuracy: 0.9867
# Epoch 61/100
# 34944/34944 [==============================] - 7s 194us/step - loss: 0.0424 - accuracy: 0.9877
# Epoch 62/100
# 34944/34944 [==============================] - 7s 202us/step - loss: 0.0427 - accuracy: 0.9874
# Epoch 63/100
# 34944/34944 [==============================] - 7s 188us/step - loss: 0.0423 - accuracy: 0.9875
# Epoch 64/100
# 34944/34944 [==============================] - 7s 207us/step - loss: 0.0416 - accuracy: 0.9876
# Epoch 65/100
# 34944/34944 [==============================] - 6s 185us/step - loss: 0.0421 - accuracy: 0.9875
# Epoch 66/100
# 34944/34944 [==============================] - 7s 198us/step - loss: 0.0407 - accuracy: 0.9880
# Epoch 67/100
# 34944/34944 [==============================] - 7s 206us/step - loss: 0.0419 - accuracy: 0.9875
# Epoch 68/100
# 34944/34944 [==============================] - 6s 181us/step - loss: 0.0415 - accuracy: 0.9878
# Epoch 69/100
# 34944/34944 [==============================] - 6s 178us/step - loss: 0.0416 - accuracy: 0.9880
# Epoch 70/100
# 34944/34944 [==============================] - 7s 194us/step - loss: 0.0413 - accuracy: 0.9879
# Epoch 71/100
# 34944/34944 [==============================] - 7s 193us/step - loss: 0.0406 - accuracy: 0.9883
# Epoch 72/100
# 34944/34944 [==============================] - 7s 187us/step - loss: 0.0407 - accuracy: 0.9877
# Epoch 73/100
# 34944/34944 [==============================] - 7s 188us/step - loss: 0.0408 - accuracy: 0.9880
# Epoch 74/100
# 34944/34944 [==============================] - 6s 184us/step - loss: 0.0401 - accuracy: 0.9883
# Epoch 75/100
# 34944/34944 [==============================] - 7s 205us/step - loss: 0.0413 - accuracy: 0.9877
# Epoch 76/100
# 34944/34944 [==============================] - 7s 210us/step - loss: 0.0405 - accuracy: 0.9884
# Epoch 77/100
# 34944/34944 [==============================] - 7s 191us/step - loss: 0.0408 - accuracy: 0.9879
# Epoch 78/100
# 34944/34944 [==============================] - 7s 205us/step - loss: 0.0399 - accuracy: 0.9882
# Epoch 79/100
# 34944/34944 [==============================] - 7s 194us/step - loss: 0.0404 - accuracy: 0.9884
# Epoch 80/100
# 34944/34944 [==============================] - 7s 196us/step - loss: 0.0396 - accuracy: 0.9889
# Epoch 81/100
# 34944/34944 [==============================] - 7s 192us/step - loss: 0.0406 - accuracy: 0.9877
# Epoch 82/100
# 34944/34944 [==============================] - 7s 192us/step - loss: 0.0403 - accuracy: 0.9881
# Epoch 83/100
# 34944/34944 [==============================] - 7s 188us/step - loss: 0.0395 - accuracy: 0.9884
# Epoch 84/100
# 34944/34944 [==============================] - 8s 218us/step - loss: 0.0395 - accuracy: 0.9887
# Epoch 85/100
# 34944/34944 [==============================] - 7s 209us/step - loss: 0.0404 - accuracy: 0.9882
# Epoch 86/100
# 34944/34944 [==============================] - 6s 186us/step - loss: 0.0394 - accuracy: 0.9887
# Epoch 87/100
# 34944/34944 [==============================] - 7s 186us/step - loss: 0.0400 - accuracy: 0.9881
# Epoch 88/100
# 34944/34944 [==============================] - 7s 189us/step - loss: 0.0397 - accuracy: 0.9882
# Epoch 89/100
# 34944/34944 [==============================] - 7s 189us/step - loss: 0.0395 - accuracy: 0.9889
# Epoch 90/100
# 34944/34944 [==============================] - 6s 180us/step - loss: 0.0404 - accuracy: 0.9884
# Epoch 91/100
# 34944/34944 [==============================] - 8s 216us/step - loss: 0.0384 - accuracy: 0.9886
# Epoch 92/100
# 34944/34944 [==============================] - 7s 205us/step - loss: 0.0391 - accuracy: 0.9883
# Epoch 93/100
# 34944/34944 [==============================] - 8s 228us/step - loss: 0.0406 - accuracy: 0.9885
# Epoch 94/100
# 34944/34944 [==============================] - 7s 202us/step - loss: 0.0391 - accuracy: 0.9886
# Epoch 95/100
# 34944/34944 [==============================] - 7s 188us/step - loss: 0.0404 - accuracy: 0.9880
# Epoch 96/100
# 34944/34944 [==============================] - 7s 190us/step - loss: 0.0394 - accuracy: 0.9882
# Epoch 97/100
# 34944/34944 [==============================] - 6s 185us/step - loss: 0.0392 - accuracy: 0.9886
# Epoch 98/100
# 34944/34944 [==============================] - 7s 190us/step - loss: 0.0396 - accuracy: 0.9885
# Epoch 99/100
# 34944/34944 [==============================] - 6s 181us/step - loss: 0.0387 - accuracy: 0.9885
# Epoch 100/100
# 34944/34944 [==============================] - 6s 185us/step - loss: 0.0397 - accuracy: 0.9884

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 3571,    75],
#        [  119, 11211]], dtype=int64)

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
# Predict probabilities for the test data.
probs = classifier.predict_proba(X_test)
auc = roc_auc_score(y_test, probs)
print('AUC: %.2f' % auc)
# Out:
# AUC: 1.00

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9870459401709402

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 3571    75]
#  [  119 11211]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97      3646
#            1       0.99      0.99      0.99     11330
#
#     accuracy                           0.99     14976
#    macro avg       0.98      0.98      0.98     14976
# weighted avg       0.99      0.99      0.99     14976

# %%
acc = accuracy_score(y_test,y_pred)*100
acc
# Out:
# 98.70459401709401
